# %% [markdown]
# # *Data Science Unit 4 Sprint 2 Assignment 1*
#
# Use TensorFlow Keras & a sample of the [Quickdraw dataset](https://github.com/googlecreativelab/quickdraw-dataset) to build a sketch classification model. The dataset has been sampled to only 10 classes and 10000 observations per class.
#
# ### Objective
#
# - Build a baseline classification model then run a few experiments with different optimizers and learning rates.
# - Don't forgot to [**switch to GPU on if you're running your notebook on Colab!**](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# ## Load Your Data

# %%
# imports in first cell 
import seaborn as sns
import pandas as pd
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# use Sequential to build out your model
from tensorflow.keras.models import Sequential

# Dense layer is used for Fully Connected Forward Feeding networks
from tensorflow.keras.layers import Dense

# %%
# load in data set
data = np.load('../quickdraw10.npz')
X = data['arr_0']
y = data['arr_1']


print(X.shape)
print(y.shape)
# Out:
# (100000, 784)
# (100000,)

# %%
class_names = ['apple',
             'anvil',
             'airplane',
             'banana',
             'The Eiffel Tower',
             'The Mona Lisa',
             'The Great Wall of China',
             'alarm clock',
             'ant',
             'asparagus']

# %%
# these are your 10 unique images
plt.figure(figsize=(10,5))
start = 0

for num, name in enumerate(class_names):
    plt.subplot(2,5, num+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X[start].reshape(28,28), cmap=plt.cm.binary)
    plt.xlabel(name)
    start += 10000
plt.show()

# %% [markdown]
# Say hello to the Quickdraw dataset.
#
# You'll be using this dataset a lot this week as an alternative to the mnist which we'll be using in the guided projects. The nice thing about this dataset is that it's simple, which allows us to focus on our model, it's various components, and gradually coming to a better understand of how to build neural networks without worrying about cleaning and preping our image data too much.

# %%
# always a good idea to shuffle your dataset 
X, y = shuffle(X, y)

# %% [markdown]
# -----
#
# ## Build Your Baseline Model
#
# Make sure that you
#
# - **Determine** the dimensionality of your input data by investigating **X**
# - **Normalize** your input data to values between 0 and 1
# - **Determine** the number of neurons in your output layer by investigating **Y**
# - **Select** `sparse_categorical_crossentropy` as your loss function.
# - **Select** `sgd` as your optimizer.
# - **Add** 3 hidden layers to your model with the following number of nodes
#     - h1 has 500 nodes
#     - h2 has 250 nodes
#     - h3 has 100 nodes
#
# - **Set** epochs to 20
# - **Use** the `validation_split` command to automatically create a training / validation dataset from within the model, so you don't have to do it yourself.
#     -  Specify a percentage such as .2 in your fit statement.
#
#
# Not sure what the various parameters are for or what what values to assign to them?
#
# - Reference the guided project notebook for Sprint 2 Module 1
# - Reference the [**Keras documentation**](https://keras.io/api/)
# - Google other examples
# - Discuss your results with classmates

# %%
# get dim of image row vectors and save to imput_dim
imput_dim = X.shape[1]
# get number of unique labels and save to n_output_nodels
n_output_nodels = np.unique(y)
# normalize image data to values between 0 and 1 (by dividing by max pixel value)
X_scaled = X/X.max()

# %%
# a check on your data prep 
assert  X_scaled.max(), "Max pixel value should be 1.0, make sure you normalize your data"

# %%
# instantiate a sequential object and call it model, then add layers to your model
model = Sequential()
# Adding h1 layer
model.add(Dense(500,
                input_dim=imput_dim,
                activation='sigmoid'
                ))
# Adding h2 layer
model.add(Dense(250,
                activation='sigmoid'))
# Adding h3 layer
model.add(Dense(100,
                activation='sigmoid'))
# Adding output layer
model.add(Dense(50,
                activation='softmax'))
# add a compile layer but don't fit your model yet
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
# number of epochs
epochs=20

# %%
# a check on your model architecture 
n_layers = len(model.get_config()["layers"])
assert n_layers == 5, "You should have 5 layers: input, h1, h2, h3, and output"

# %%
# check out your model summary
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 500)               392500
# _________________________________________________________________
# dense_36 (Dense)             (None, 250)               125250
# _________________________________________________________________
# dense_37 (Dense)             (None, 100)               25100
# _________________________________________________________________
# dense_38 (Dense)             (None, 50)                5050
# =================================================================
# Total params: 547,900
# Trainable params: 547,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit your model and save training resuts to history
history = model.fit(X_scaled, y,
                    epochs=epochs,
                    # test set will be generated within the model
                    validation_split=0.2
                   )
# Out:
# Epoch 1/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 2.5245 - accuracy: 0.1053 - val_loss: 2.2973 - val_accuracy: 0.1882
# Epoch 2/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 2.2898 - accuracy: 0.1484 - val_loss: 2.2610 - val_accuracy: 0.2339
# Epoch 3/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 2.2189 - accuracy: 0.2575 - val_loss: 1.9829 - val_accuracy: 0.3040
# Epoch 4/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.8819 - accuracy: 0.3953 - val_loss: 1.6508 - val_accuracy: 0.5031
# Epoch 5/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.5873 - accuracy: 0.5050 - val_loss: 1.4036 - val_accuracy: 0.5823
# Epoch 6/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.3563 - accuracy: 0.5814 - val_loss: 1.2256 - val_accuracy: 0.6271
# Epoch 7/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.1911 - accuracy: 0.6296 - val_loss: 1.1085 - val_accuracy: 0.6503
# Epoch 8/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.0943 - accuracy: 0.6614 - val_loss: 1.0313 - val_accuracy: 0.6854
# Epoch 9/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.0298 - accuracy: 0.6847 - val_loss: 0.9862 - val_accuracy: 0.6966
# Epoch 10/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.9863 - accuracy: 0.6984 - val_loss: 0.9572 - val_accuracy: 0.7089
# Epoch 11/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.9590 - accuracy: 0.7074 - val_loss: 0.9332 - val_accuracy: 0.7143
# Epoch 12/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.9347 - accuracy: 0.7187 - val_loss: 0.9095 - val_accuracy: 0.7264
# Epoch 13/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.9224 - accuracy: 0.7232 - val_loss: 0.8898 - val_accuracy: 0.7344
# Epoch 14/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8947 - accuracy: 0.7330 - val_loss: 0.8738 - val_accuracy: 0.7387
# Epoch 15/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8836 - accuracy: 0.7376 - val_loss: 0.8560 - val_accuracy: 0.7451
# Epoch 16/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8657 - accuracy: 0.7412 - val_loss: 0.8430 - val_accuracy: 0.7480
# Epoch 17/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8514 - accuracy: 0.7463 - val_loss: 0.8317 - val_accuracy: 0.7526
# Epoch 18/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8416 - accuracy: 0.7484 - val_loss: 0.8201 - val_accuracy: 0.7557
# Epoch 19/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8278 - accuracy: 0.7532 - val_loss: 0.8081 - val_accuracy: 0.7600
# Epoch 20/20
# 2500/2500 [==============================] - 8s 3ms/step - loss: 0.8151 - accuracy: 0.7580 - val_loss: 0.7969 - val_accuracy: 0.7632

# %% [markdown]
# ----
# ### Visualize the results
#
# - Move results in `history` in a dataframe
# - Use [**Seaborn**](https://seaborn.pydata.org/generated/seaborn.lineplot.html) to create lineplots for both loss and accuracy by epoch.
# - Analyze the results and write a couple of obsverations.
#
# At what point should we have stopped training the model and why?

# %%
# YOUR CODE HERE
df = pd.DataFrame(history.history)

# %%
# a check on our model training
assert df.shape[0] == 20, "df should have the training results from 20 epochs"

# %%
# use the plotting method in your dataframe to plot the modeling results 

# YOUR CODE HERE
epochs = [i for i in range(len(history.history['loss']))]
sns.lineplot(epochs, history.history['loss'], label="train")
sns.lineplot(epochs, history.history['val_loss'], label="test")
# Out:
# C:\Users\justi\.conda\envs\U4-S2-NN\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\justi\.conda\envs\U4-S2-NN\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:>

# %% [markdown]
# ### Observations
#
# Based on the plot of the training and validation loss answer the following questions.

# %% [markdown]
# **Was our model able to learn over the course of the 20 epochs? Why or why not?**

# %% [markdown]
# Answer: Are model was able to learn great over 20 epochs. It has due to seeing the loss becoming smaller the more epochs it went through

# %% [markdown]
# **Is our model overfitting? Why or why not?**

# %% [markdown]
# Answer: Are model is not overfitting due to them being stay near each other the entire time it is learning.

# %% [markdown]
# **Could the model score benefit from additional epochs? Why or why not?**

# %% [markdown]
# Answer: I do not think so due to them being so close together at the end.

# %% [markdown]
# -----
# ## Change Optimizers
#
# Let's compare model performance between difference optimizers.
# - Build a new model, identical as the last one but using `adam` for the optimizer.
# - Visualize the training results just as we did for the last model.
# - Save modeling results to adam_history so we don't erase the results from the previous model run

# %%
# train same model as above but use sgd if you used adam previously ( or use adam if you used sgd previously)

# YOUR CODE HERE
# instantiate a sequential object and call it model, then add layers to your model
model = Sequential()
# Adding h1 layer
model.add(Dense(500,
                input_dim=imput_dim,
                activation='sigmoid'
                ))
# Adding h2 layer
model.add(Dense(250,
                activation='sigmoid'))
# Adding h3 layer
model.add(Dense(100,
                activation='sigmoid'))
# Adding output layer
model.add(Dense(50,
                activation='softmax'))
# add a compile layer but don't fit your model yet
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# number of epochs
epochs=20

# %%
# a check that we're using the correct optimizer in this model
opt_name = model.optimizer.get_config()["name"]
assert opt_name == "Adam", "you need to use adam for the optimizer in this model."

# %%
# YOUR CODE HERE
# fit your model and save training resuts to history
history2 = model.fit(X_scaled, y,
                    epochs=epochs,
                    # test set will be generated within the model
                    validation_split=0.2
                   )
# Out:
# Epoch 1/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 1.1569 - accuracy: 0.6354 - val_loss: 0.5424 - val_accuracy: 0.8364
# Epoch 2/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.5114 - accuracy: 0.8427 - val_loss: 0.4870 - val_accuracy: 0.8511
# Epoch 3/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.4203 - accuracy: 0.8732 - val_loss: 0.4189 - val_accuracy: 0.8729
# Epoch 4/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.3581 - accuracy: 0.8923 - val_loss: 0.4148 - val_accuracy: 0.8729
# Epoch 5/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.3117 - accuracy: 0.9055 - val_loss: 0.4091 - val_accuracy: 0.8773
# Epoch 6/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.2721 - accuracy: 0.9182 - val_loss: 0.3907 - val_accuracy: 0.8882
# Epoch 7/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.2367 - accuracy: 0.9294 - val_loss: 0.4081 - val_accuracy: 0.8837
# Epoch 8/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.2066 - accuracy: 0.9384 - val_loss: 0.4208 - val_accuracy: 0.8823
# Epoch 9/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.1774 - accuracy: 0.9469 - val_loss: 0.4331 - val_accuracy: 0.8859
# Epoch 10/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.1542 - accuracy: 0.9548 - val_loss: 0.4714 - val_accuracy: 0.8797
# Epoch 11/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.1324 - accuracy: 0.9613 - val_loss: 0.4822 - val_accuracy: 0.8835
# Epoch 12/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.1179 - accuracy: 0.9652 - val_loss: 0.4928 - val_accuracy: 0.8832
# Epoch 13/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.1027 - accuracy: 0.9704 - val_loss: 0.5249 - val_accuracy: 0.8816
# Epoch 14/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0888 - accuracy: 0.9735 - val_loss: 0.5330 - val_accuracy: 0.8824
# Epoch 15/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0816 - accuracy: 0.9750 - val_loss: 0.5775 - val_accuracy: 0.8820
# Epoch 16/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.0723 - accuracy: 0.9783 - val_loss: 0.6173 - val_accuracy: 0.8777
# Epoch 17/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0621 - accuracy: 0.9818 - val_loss: 0.6393 - val_accuracy: 0.8793
# Epoch 18/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.0593 - accuracy: 0.9819 - val_loss: 0.6448 - val_accuracy: 0.8793
# Epoch 19/20
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0484 - accuracy: 0.9851 - val_loss: 0.6668 - val_accuracy: 0.8819
# Epoch 20/20
# 2500/2500 [==============================] - 9s 3ms/step - loss: 0.0498 - accuracy: 0.9845 - val_loss: 0.6866 - val_accuracy: 0.8795

# %%
epochs = [i for i in range(len(history2.history['loss']))]
sns.lineplot(epochs, history2.history['loss'], label="train")
sns.lineplot(epochs, history2.history['val_loss'], label="test")
# Out:
# C:\Users\justi\.conda\envs\U4-S2-NN\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\justi\.conda\envs\U4-S2-NN\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:>

# %% [markdown]
# ### Observations
#
# This plot should look very different from the previous plot. Based on the plot of the training and validation loss answer the following questions.

# %% [markdown]
# **Is our model overfitting? Why or why not?**

# %% [markdown]
# Answer: Yes they are due to them widening apart as they are learning. Are mean loss is actually increasing/

# %% [markdown]
# **Could our model's performance improve by training on more than 20 epochs? Why or why not?**

# %% [markdown]
# Answer: No it would not due to the mean loss is increasing over the more epochs we have.

# %% [markdown]
# **Assuming that you want to stick to this model architecture, what can you do to avoid overfitting?**

# %% [markdown]
# Answer: We could mess around with adding some normalizers and dropouts in are layers to maybe help with are overfitting.

# %% [markdown]
# ------
# # Conclusion
#
# What you have observed by comparing the two models that are identitical, except for the optimizer, is that the choice of the optimizer can have a very big influence in the training outcome of ML models in general and in a neural networks in particuar.
#
# You might not actually know
#
# - why changing the optimizer from Stocastic Gradient Descent over to Adam made a difference.
# - how Gradient Desecent works
# - or that Adam is known as Adaptive Gradient Descent (i.e. is it a different version of ordinary Gradient Descent).
#
# But that's ok - tomorrow's lesson will be a deep dive into Gradient Descent. You'll learn the theory of Gradient Descent, we'll code up Gradient Descent from scratch, and we'll talk about how Adam is different from ordinary Gradient Descent.

# %% [markdown]
# -----
# # Preparation for Tomorrow
#
# In Preparation for tomorrow, you might need to watch a few videos. I say might because you may or may not already be comfortable with multi-variate calculus.
#
# ### Theory of Calculus
# The theory of Gradient Descent rest on [**the derivative from Calculus**](https://www.youtube.com/watch?v=WUvTyaaNkzM). If you've never taken a Calculus course before, or are a bit rusty, definitely watch this video in preparation for tomorrow's lesson. The take away here is to conceptually understand the derivative, you won't be asked to actually calculate any derivatives by hand.
#
# ### The Gradient - a multi-dimensional derivative
# Once you've watched the previous video, you are now set up to  understand how to conceptualize a derivative in an N-dimensional space (where N is any number ranging from 2, 3, 4, ..., all the way to a very large number of dimensions N ) [**This video visually explains the multi-dimensional derivative called the Gradient visually**](https://www.youtube.com/watch?v=GkB4vW16QHI) - and that's the take away. This point of this video is to help you understand the Gradient visually using 3D surfaces. You should also know that the Gradient is made of up partial derivatives, more on this tomorrow.
#
# ### Contour Maps
# It is very common to visual 3D surfaces as 2D contour maps - and we'll be making a lot of use of contour maps to understand Gradient Descent. Watch this video in order to [**understand the relationship between 3D surfaces and 2D contour maps**](https://www.youtube.com/watch?v=acdX4YamDtU)
#
# ### The Calculus of Backpropagation
#
# Unlike standard Sklearn ML models, neural networks use not just Gradient Descent but also something called Backpropagatin in order to learn from the data. [**In order to understand how backpropagation works, you need to understand the Chain Rule in Calculus**](https://www.youtube.com/watch?v=acdX4YamDtU). The take away here is to understand how a partial derivative can be decomposed into a product of multiple derivatives.

# %% [markdown]
# ------
# # Stretch Goals
#
# ### This section is optional!
#
# Only after you've completed the above work and watched the recommended videos, are you then encouraged to experiment with building a few more models and analyze their results.
#
# Here are some suggestions to help you get started.
#
# - Train the same model using the Sigmoid activation fucntion and the Relu activation function and note the difference in their learning outcomes.  [**Keras docs on activation fucntions**](https://keras.io/api/layers/activations/). We'll cover the Relu activation function in Sprint 2 Module 3.
# - Train the same model using Normalized and non-Normalized data and note the difference in their learning outcomes.
#
#
# The objective here is to give you an oppertunity to get more practice with the Keras API (i.e. building models) and running a couple of experiments to help set you up for future lessons. In order words, we'll be discussing different activation functions and the affect of Normalized data on model training.
